# %%
#setup

import sys
import os
import numpy as np
import pandas as pd
import sqlite3 as sql

import matplotlib.pyplot as plt
import matplotlib.dates as mdates

import matplotlib.dates as mdates
from datetime import datetime

# %%
conn = sql.connect('film_locations.db')
film_locations = pd.read_csv('Film_Locations_in_San_Francisco.csv', encoding = 'unicode_escape')
film_locations.to_sql('Film_Locations_in_San_Francisco', conn, if_exists='replace')

# %%
#reading entire dataset from csv file 
#Dataset Obtained: https://www.kaggle.com

pd.read_csv('Film_Locations_in_San_Francisco.csv')
# Out:
#                          Title  Release Year  \
# 0                          180          2011
# 1                          180          2011
# 2                          180          2011
# 3                          180          2011
# 4                          180          2011
# 5                          180          2011
# 6                          180          2011
# 7                          180          2011
# 8       24 Hours on Craigslist          2005
# 9        40 Days and 40 Nights          2002
# 10       40 Days and 40 Nights          2002
# 11                    48 Hours          1982
# 12              50 First Dates          2004
# 13          A Jitney Elopement          1915
# 14          A Jitney Elopement          1915
# 15        A Night Full of Rain          1978
# 16        A Night Full of Rain          1978
# 17        A Night Full of Rain          1978
# 18        A Night Full of Rain          1978
# 19          A Smile Like Yours          1997
# ...

# %%
# graph showing most used locations

fracs = [30, 15, 45, 10]
colors = ['b', 'g', 'r', 'w']

fig, ax = plt.subplots(figsize=(6, 6))  
pie = ax.pie(fracs, colors=colors, explode=(0, 0, 0, 0), shadow=False,
             labels=['A', 'B', 'C', 'D'])

# %%
pd.read_sql_query("""
    SELECT Title, Release Year, Locations FROM Film_Locations_in_San_Francisco
    ORDER BY Release Year
    DESC;
""", conn)
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# /anaconda3/lib/python3.7/site-packages/pandas/io/sql.py in execute(self, *args, **kwargs)
#    1430             else:
# -> 1431                 cur.execute(*args)
#    1432             return cur
#
# OperationalError: near "Year": syntax error
#
# During handling of the above exception, another exception occurred:
#
# DatabaseError                             Traceback (most recent call last)
# <ipython-input-35-0bbb128feea8> in <module>
#       3     ORDER BY Release Year
#       4     DESC;
# ----> 5 """, conn);
#
# /anaconda3/lib/python3.7/site-packages/pandas/io/sql.py in read_sql_query(sql, con, index_col, coerce_float, params, parse_dates, chunksize)
#     312     return pandas_sql.read_query(
#     313         sql, index_col=index_col, params=params, coerce_float=coerce_float,
# ...
