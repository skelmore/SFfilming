# %%
#setup

import sys
import os
import numpy as np
import pandas as pd
import sqlite3 as sql

import matplotlib.pyplot as plt
import matplotlib.dates as mdates

import matplotlib.dates as mdates
from datetime import datetime

# %%
#reading data from csv file 
#Dataset Obtained: https://www.kaggle.com

pd.read_csv('Film_Locations_in_San_Francisco.csv')
# Out:
#                          Title  Release Year  \
# 0                          180          2011
# 1                          180          2011
# 2                          180          2011
# 3                          180          2011
# 4                          180          2011
# 5                          180          2011
# 6                          180          2011
# 7                          180          2011
# 8       24 Hours on Craigslist          2005
# 9        40 Days and 40 Nights          2002
# 10       40 Days and 40 Nights          2002
# 11                    48 Hours          1982
# 12              50 First Dates          2004
# 13          A Jitney Elopement          1915
# 14          A Jitney Elopement          1915
# 15        A Night Full of Rain          1978
# 16        A Night Full of Rain          1978
# 17        A Night Full of Rain          1978
# 18        A Night Full of Rain          1978
# 19          A Smile Like Yours          1997
# ...

# %%
#graph

plt.plot([1,2,3,4], [1,4,9,16], color="green", linestyle="dashdot")
plt.plot([-1,3,6,7], [1,3,9,17], color="blue", linestyle="dashdot")
plt.ylabel ("location", color="red")
plt.xlabel ("year", color="red")
plt.show()

# %%
# graph

fracs = [30, 15, 45, 10]
colors = ['b', 'g', 'r', 'w']

fig, ax = plt.subplots(figsize=(6, 6))  # make the plot square
pie = ax.pie(fracs, colors=colors, explode=(0, 0, 0.05, 0), shadow=True,
             labels=['A', 'B', 'C', 'D'])
